# %% [markdown]
# # BDTA 16: Calculate Relative Frequencies of Vocabulary
#
# This takes a folder and builds a table of all words calculating their relative frequencies. It uses the [Pandas Data Analysis Library](http://pandas.pydata.org/).

# %% [markdown]
# Here is a way to get a folder of Gutenberg texts from NLTK if you don't have any yourself.

# %%
# import nltk
# use NTLK Gutenberg for convenience, but you could read any directory
# directory = nltk.data.find('corpora/gutenberg')

# %% [markdown]
# ## Identify the folder
#
# Here we check to see what folders of text we have. You can use different commands to navigate until you get to where your folder is.

# %%
ls
# Out:
# 2003-04FolderShortSIDToday/           Principal Component Analysis.ipynb
# Calculate Relative Frequencies.ipynb* Second Notebook.ipynb
# ExampleTable.csv                      Sentiment Over a Text.ipynb
# Extracting Dictionaries.ipynb         Test.txt
# FrequenciesResultsShort.csv           Texts/
# FrequenciesResultsShortFlip.csv       Third Notebook.ipynb
# Hume Enquiry.txt                      Web Scraping.ipynb
# My First Notebook.ipynb               Working with a Corpus.ipynb
# Parsing File Names.ipynb              inquirerbasic.csv

# %% [markdown]
# Now we assign the name of the folder to a variable.

# %%
directory = "2003-04FolderShortSIDToday"

# %% [markdown]
# ## Process text files in folder
#
# This goes through the folder and processes all the text files. It tokenizes, counts, calculates relative frequencies and then adds to a dictionary for each file.

# %%
import glob, re, os, collections

# this will track our frequencies
docs = {}

# go through each txt file in the directory 
for file in glob.glob(directory + "/*.txt"):
    
    # read file as Latin 1 (remove encoding for UTF-8)
    with open(file, encoding="ISO-8859-1") as f:
        text = f.read();
        
        # tokenize
        tokens = re.findall(r'\b\w[\w-]*\b', text.lower())
        count = len(tokens)
        
        # convert to relative freqs
        relativefreqs = {}
        for word, raw in collections.Counter(tokens).items():
            
            # gather only words with alphabetical characters, discard numbers
            if word.isalpha():
                relativefreqs[word] = raw/count
            
        # add this document's relative freqs to our dictionary
        docs[os.path.basename(file)] = relativefreqs
        
print("Files processed: " + str(len(docs))) # prints out the type and length
# Out:
# Files processed: 16

# %% [markdown]
# ## Convert into a dataframe
#
# Now we convert the dictionary into a dataframe and show the top 20 rows.

# %%
import pandas as pd
df = pd.DataFrame(docs)
df.head(20)
# Out:
#               2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts--An_Urgent_Need.pdf.txt  \
# a                                                      0.011111
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-01_SIDToday_-_Practical_Jokes_and_April_Fools.pdf.txt  \
# a                                                      0.016750
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                  0.001675
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-02_SIDToday_-_Last_QUICKMASK_Training_Today.pdf.txt  \
# a                                                      0.005587
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                  0.005587
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mind_Session_--_Today.pdf.txt  \
# a                                                      0.009174
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-02_SIDToday_-_SIGINT_Strategy__The_Importance_of_Common_Goals.pdf.txt  \
# a                                                      0.004651
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                  0.002326
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                            0.002326
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FREEDOM.pdf.txt  \
# a                                                      0.011527
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                             0.002882
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-03_SIDToday_-_SID_Leadership_Transition_Passing_the_Baton.pdf.txt  \
# a                                                      0.016035
# abilities                                                   NaN
# ability                                                0.001458
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                 0.001458
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                           0.001458
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_Quarter_Tools_Courses.pdf.txt  \
# a                                                      0.002481
# abilities                                                   NaN
# ability                                                     NaN
# able                                                   0.001241
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                 0.001241
# accessible                                                  NaN
# accommodate                                            0.002481
# accomplished                                                NaN
# accordance                                             0.001241
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-04_SIDToday_-_Profiles_SID_Communications_and_Support_Operations.pdf.txt  \
# a                                                      0.007722
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt  \
# a                                                    0.013043
# abilities                                                 NaN
# ability                                                   NaN
# able                                                      NaN
# about                                                0.004348
# above                                                     NaN
# abstruse                                             0.002174
# accept                                                    NaN
# accepted                                                  NaN
# access                                                    NaN
# accessible                                                NaN
# accommodate                                               NaN
# accomplished                                              NaN
# accordance                                                NaN
# accordingly                                               NaN
# account                                                   NaN
# accounts                                                  NaN
# accurate                                             0.002174
# achieving                                            0.002174
# acquisition                                               NaN
#
#               2003-04-07_SIDToday_-_ICAP_Call_for_Applications.pdf.txt  \
# a                                                      0.006873
# abilities                                              0.001718
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                               0.003436
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_Efforts_on_Iraq.pdf.txt  \
# a                                                      0.004577
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-08_SIDToday_-_Profile_SID_Registry_-_Grand_Central.pdf.txt  \
# a                                                      0.014563
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                  0.002427
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                            0.004854
#
#               2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf.txt  \
# a                                                      0.004785
# abilities                                              0.002392
# ability                                                     NaN
# able                                                        NaN
# about                                                  0.004785
# above                                                  0.002392
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-09_SIDToday_-_Profile_SIGINT_Support_Services.pdf.txt  \
# a                                                      0.006098
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                0.003049
# accounts                                               0.003049
# accurate                                               0.003049
# achieving                                                   NaN
# acquisition                                                 NaN
#
#               2003-04-09_SIDToday_-_Uncovering_North_Korea_Nuclear_Programs.pdf.txt
# a                                                      0.012422
# abilities                                                   NaN
# ability                                                     NaN
# able                                                        NaN
# about                                                       NaN
# above                                                       NaN
# abstruse                                                    NaN
# accept                                                      NaN
# accepted                                                    NaN
# access                                                      NaN
# accessible                                                  NaN
# accommodate                                                 NaN
# accomplished                                                NaN
# accordance                                                  NaN
# accordingly                                                 NaN
# account                                                     NaN
# accounts                                                    NaN
# accurate                                                    NaN
# achieving                                                   NaN
# acquisition                                                 NaN

# %%
df.describe()
# Out:
#        2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts--An_Urgent_Need.pdf.txt  \
# count                                         154.000000
# mean                                            0.006061
# std                                             0.004787
# min                                             0.003704
# 25%                                             0.003704
# 50%                                             0.003704
# 75%                                             0.007407
# max                                             0.044444
#
#        2003-04-01_SIDToday_-_Practical_Jokes_and_April_Fools.pdf.txt  \
# count                                         316.000000
# mean                                            0.003011
# std                                             0.004549
# min                                             0.001675
# 25%                                             0.001675
# 50%                                             0.001675
# 75%                                             0.003350
# max                                             0.058626
#
#        2003-04-02_SIDToday_-_Last_QUICKMASK_Training_Today.pdf.txt  \
# count                                         104.000000
# mean                                            0.008380
# std                                             0.004799
# min                                             0.005587
# 25%                                             0.005587
# 50%                                             0.005587
# 75%                                             0.011173
# max                                             0.039106
#
#        2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mind_Session_--_Today.pdf.txt  \
# count                                         120.000000
# mean                                            0.007569
# std                                             0.005138
# min                                             0.004587
# 25%                                             0.004587
# 50%                                             0.004587
# 75%                                             0.009174
# max                                             0.036697
#
#        2003-04-02_SIDToday_-_SIGINT_Strategy__The_Importance_of_Common_Goals.pdf.txt  \
# count                                         197.000000
# mean                                            0.004805
# std                                             0.006731
# min                                             0.002326
# 25%                                             0.002326
# 50%                                             0.002326
# 75%                                             0.004651
# max                                             0.067442
#
#        2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FREEDOM.pdf.txt  \
# count                                         178.000000
# mean                                            0.005197
# std                                             0.005715
# min                                             0.002882
# 25%                                             0.002882
# 50%                                             0.002882
# 75%                                             0.005764
# max                                             0.043228
#
#        2003-04-03_SIDToday_-_SID_Leadership_Transition_Passing_the_Baton.pdf.txt  \
# count                                         308.000000
# mean                                            0.003157
# std                                             0.005040
# min                                             0.001458
# 25%                                             0.001458
# 50%                                             0.001458
# 75%                                             0.002915
# max                                             0.046647
#
#        2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_Quarter_Tools_Courses.pdf.txt  \
# count                                         198.000000
# mean                                            0.002983
# std                                             0.005647
# min                                             0.001241
# 25%                                             0.001241
# 50%                                             0.001241
# 75%                                             0.002481
# max                                             0.057072
#
#        2003-04-04_SIDToday_-_Profiles_SID_Communications_and_Support_Operations.pdf.txt  \
# count                                         127.000000
# mean                                            0.006992
# std                                             0.006224
# min                                             0.003861
# 25%                                             0.003861
# 50%                                             0.003861
# 75%                                             0.007722
# max                                             0.030888
#
#        2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt  \
# count                                       259.000000
# mean                                          0.003618
# std                                           0.004785
# min                                           0.002174
# 25%                                           0.002174
# 50%                                           0.002174
# 75%                                           0.004348
# max                                           0.054348
#
#        2003-04-07_SIDToday_-_ICAP_Call_for_Applications.pdf.txt  \
# count                                         240.000000
# mean                                            0.003852
# std                                             0.005564
# min                                             0.001718
# 25%                                             0.001718
# 50%                                             0.001718
# 75%                                             0.003436
# max                                             0.058419
#
#        2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_Efforts_on_Iraq.pdf.txt  \
# count                                         213.000000
# mean                                            0.004458
# std                                             0.006462
# min                                             0.002288
# 25%                                             0.002288
# 50%                                             0.002288
# 75%                                             0.004577
# max                                             0.070938
#
#        2003-04-08_SIDToday_-_Profile_SID_Registry_-_Grand_Central.pdf.txt  \
# count                                         208.000000
# mean                                            0.004411
# std                                             0.004810
# min                                             0.002427
# 25%                                             0.002427
# 50%                                             0.002427
# 75%                                             0.004854
# max                                             0.033981
#
#        2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf.txt  \
# count                                         207.000000
# mean                                            0.004577
# std                                             0.006061
# min                                             0.002392
# 25%                                             0.002392
# 50%                                             0.002392
# 75%                                             0.004785
# max                                             0.057416
#
#        2003-04-09_SIDToday_-_Profile_SIGINT_Support_Services.pdf.txt  \
# count                                         167.000000
# mean                                            0.005349
# std                                             0.005211
# min                                             0.003049
# 25%                                             0.003049
# 50%                                             0.003049
# 75%                                             0.006098
# max                                             0.033537
#
#        2003-04-09_SIDToday_-_Uncovering_North_Korea_Nuclear_Programs.pdf.txt
# count                                         172.000000
# mean                                            0.005525
# std                                             0.005854
# min                                             0.003106
# 25%                                             0.003106
# 50%                                             0.003106
# 75%                                             0.006211
# max                                             0.046584

# %% [markdown]
# ## Sort by summed relative frequencies
#
# Now we add a column with the sum of the relative frequencies for the documents and sort by that to see the high frequency words.

# %%
# sort the data frame by sum
df['Sum'] = df.sum(axis=1)
df.sort_values("Sum", ascending=False, inplace=True)
df[:20]
# Out:
#         2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts--An_Urgent_Need.pdf.txt  \
# the                                              0.014815
# to                                               0.044444
# and                                              0.014815
# of                                               0.011111
# u                                                0.007407
# is                                               0.018519
# in                                               0.011111
# on                                               0.011111
# sid                                              0.007407
# sigint                                           0.014815
# a                                                0.011111
# si                                               0.018519
# s                                                0.011111
# fouo                                             0.007407
# ï                                                0.003704
# for                                              0.014815
# that                                             0.007407
# from                                             0.007407
# be                                               0.007407
# can                                              0.007407
#
#         2003-04-01_SIDToday_-_Practical_Jokes_and_April_Fools.pdf.txt  \
# the                                              0.058626
# to                                               0.030151
# and                                              0.023451
# of                                               0.025126
# u                                                0.011725
# is                                               0.008375
# in                                               0.015075
# on                                               0.018425
# sid                                                   NaN
# sigint                                           0.001675
# a                                                0.016750
# si                                               0.003350
# s                                                0.008375
# fouo                                             0.001675
# ï                                                0.001675
# for                                              0.001675
# that                                             0.013400
# from                                             0.008375
# be                                               0.003350
# can                                              0.005025
#
#         2003-04-02_SIDToday_-_Last_QUICKMASK_Training_Today.pdf.txt  \
# the                                              0.039106
# to                                               0.022346
# and                                              0.016760
# of                                               0.011173
# u                                                0.016760
# is                                               0.016760
# in                                               0.005587
# on                                               0.011173
# sid                                                   NaN
# sigint                                           0.005587
# a                                                0.005587
# si                                               0.011173
# s                                                     NaN
# fouo                                             0.016760
# ï                                                0.016760
# for                                              0.011173
# that                                                  NaN
# from                                             0.011173
# be                                               0.005587
# can                                              0.011173
#
#         2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mind_Session_--_Today.pdf.txt  \
# the                                              0.036697
# to                                               0.027523
# and                                              0.013761
# of                                               0.009174
# u                                                0.018349
# is                                               0.013761
# in                                               0.018349
# on                                               0.018349
# sid                                              0.018349
# sigint                                           0.013761
# a                                                0.009174
# si                                               0.009174
# s                                                0.009174
# fouo                                             0.009174
# ï                                                0.013761
# for                                              0.004587
# that                                                  NaN
# from                                             0.009174
# be                                               0.009174
# can                                              0.013761
#
#         2003-04-02_SIDToday_-_SIGINT_Strategy__The_Importance_of_Common_Goals.pdf.txt  \
# the                                              0.067442
# to                                               0.032558
# and                                              0.016279
# of                                               0.032558
# u                                                0.011628
# is                                               0.018605
# in                                               0.011628
# on                                               0.006977
# sid                                              0.009302
# sigint                                           0.030233
# a                                                0.004651
# si                                               0.004651
# s                                                0.009302
# fouo                                             0.011628
# ï                                                0.002326
# for                                              0.009302
# that                                             0.009302
# from                                             0.004651
# be                                               0.009302
# can                                              0.006977
#
#         2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FREEDOM.pdf.txt  \
# the                                              0.043228
# to                                               0.025937
# and                                              0.043228
# of                                               0.031700
# u                                                0.005764
# is                                               0.008646
# in                                               0.025937
# on                                               0.017291
# sid                                              0.005764
# sigint                                           0.002882
# a                                                0.011527
# si                                               0.014409
# s                                                0.011527
# fouo                                             0.002882
# ï                                                0.005764
# for                                              0.005764
# that                                             0.002882
# from                                             0.005764
# be                                               0.002882
# can                                              0.005764
#
#         2003-04-03_SIDToday_-_SID_Leadership_Transition_Passing_the_Baton.pdf.txt  \
# the                                              0.046647
# to                                               0.036443
# and                                              0.040816
# of                                               0.018950
# u                                                0.007289
# is                                               0.010204
# in                                               0.020408
# on                                               0.004373
# sid                                              0.001458
# sigint                                           0.007289
# a                                                0.016035
# si                                               0.002915
# s                                                0.011662
# fouo                                             0.005831
# ï                                                0.001458
# for                                              0.010204
# that                                             0.018950
# from                                             0.002915
# be                                               0.011662
# can                                              0.002915
#
#         2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_Quarter_Tools_Courses.pdf.txt  \
# the                                              0.012407
# to                                               0.057072
# and                                              0.007444
# of                                               0.002481
# u                                                0.007444
# is                                               0.003722
# in                                               0.003722
# on                                               0.001241
# sid                                              0.001241
# sigint                                                NaN
# a                                                0.002481
# si                                               0.002481
# s                                                     NaN
# fouo                                             0.006203
# ï                                                0.023573
# for                                              0.004963
# that                                                  NaN
# from                                             0.002481
# be                                               0.002481
# can                                              0.003722
#
#         2003-04-04_SIDToday_-_Profiles_SID_Communications_and_Support_Operations.pdf.txt  \
# the                                              0.030888
# to                                               0.023166
# and                                              0.030888
# of                                               0.027027
# u                                                0.019305
# is                                               0.007722
# in                                                    NaN
# on                                               0.003861
# sid                                              0.030888
# sigint                                           0.023166
# a                                                0.007722
# si                                               0.007722
# s                                                     NaN
# fouo                                             0.011583
# ï                                                0.011583
# for                                              0.003861
# that                                                  NaN
# from                                             0.007722
# be                                               0.003861
# can                                              0.007722
#
#         2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt  \
# the                                            0.054348
# to                                             0.015217
# and                                            0.021739
# of                                             0.039130
# u                                              0.008696
# is                                             0.013043
# in                                             0.023913
# on                                             0.008696
# sid                                                 NaN
# sigint                                         0.002174
# a                                              0.013043
# si                                             0.004348
# s                                                   NaN
# fouo                                           0.006522
# ï                                              0.002174
# for                                            0.002174
# that                                           0.017391
# from                                           0.008696
# be                                             0.006522
# can                                            0.004348
#
#         2003-04-07_SIDToday_-_ICAP_Call_for_Applications.pdf.txt  \
# the                                              0.058419
# to                                               0.020619
# and                                              0.037801
# of                                               0.020619
# u                                                0.018900
# is                                               0.010309
# in                                               0.003436
# on                                               0.013746
# sid                                              0.008591
# sigint                                           0.001718
# a                                                0.006873
# si                                               0.003436
# s                                                0.001718
# fouo                                             0.006873
# ï                                                0.015464
# for                                              0.018900
# that                                             0.005155
# from                                             0.006873
# be                                               0.018900
# can                                              0.005155
#
#         2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_Efforts_on_Iraq.pdf.txt  \
# the                                              0.070938
# to                                               0.043478
# and                                              0.022883
# of                                               0.025172
# u                                                0.009153
# is                                               0.006865
# in                                               0.013730
# on                                               0.016018
# sid                                              0.002288
# sigint                                           0.009153
# a                                                0.004577
# si                                               0.013730
# s                                                0.022883
# fouo                                             0.002288
# ï                                                0.004577
# for                                              0.011442
# that                                             0.018307
# from                                             0.006865
# be                                               0.002288
# can                                              0.004577
#
#         2003-04-08_SIDToday_-_Profile_SID_Registry_-_Grand_Central.pdf.txt  \
# the                                              0.031553
# to                                               0.031553
# and                                              0.021845
# of                                               0.021845
# u                                                0.016990
# is                                               0.012136
# in                                                    NaN
# on                                               0.007282
# sid                                              0.033981
# sigint                                           0.007282
# a                                                0.014563
# si                                               0.004854
# s                                                0.009709
# fouo                                             0.012136
# ï                                                0.007282
# for                                              0.004854
# that                                             0.002427
# from                                             0.012136
# be                                               0.004854
# can                                              0.004854
#
#         2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf.txt  \
# the                                              0.057416
# to                                               0.045455
# and                                              0.035885
# of                                               0.019139
# u                                                0.014354
# is                                               0.009569
# in                                               0.011962
# on                                               0.009569
# sid                                              0.011962
# sigint                                                NaN
# a                                                0.004785
# si                                               0.004785
# s                                                     NaN
# fouo                                             0.011962
# ï                                                0.002392
# for                                              0.009569
# that                                             0.007177
# from                                             0.004785
# be                                               0.007177
# can                                              0.004785
#
#         2003-04-09_SIDToday_-_Profile_SIGINT_Support_Services.pdf.txt  \
# the                                              0.030488
# to                                               0.015244
# and                                              0.018293
# of                                               0.024390
# u                                                0.021341
# is                                               0.015244
# in                                               0.006098
# on                                               0.009146
# sid                                              0.024390
# sigint                                           0.024390
# a                                                0.006098
# si                                               0.006098
# s                                                0.003049
# fouo                                             0.015244
# ï                                                0.009146
# for                                              0.009146
# that                                             0.009146
# from                                             0.006098
# be                                               0.006098
# can                                              0.009146
#
#         2003-04-09_SIDToday_-_Uncovering_North_Korea_Nuclear_Programs.pdf.txt  \
# the                                              0.046584
# to                                               0.027950
# and                                              0.031056
# of                                               0.018634
# u                                                0.015528
# is                                               0.009317
# in                                                    NaN
# on                                               0.006211
# sid                                              0.003106
# sigint                                           0.012422
# a                                                0.012422
# si                                               0.021739
# s                                                0.034161
# fouo                                             0.003106
# ï                                                0.003106
# for                                                   NaN
# that                                             0.009317
# from                                             0.009317
# be                                               0.006211
# can                                              0.009317
#
#              Sum
# the     1.399206
# to      0.998313
# and     0.793887
# of      0.676459
# u       0.421267
# is      0.365594
# in      0.341910
# on      0.326938
# sid     0.317452
# sigint  0.313093
# a       0.294800
# si      0.266771
# s       0.265345
# fouo    0.262547
# ï       0.249487
# for     0.244860
# that    0.241725
# from    0.228864
# be      0.215515
# can     0.213297

# %% [markdown]
# We can calculate the length or number of rows in the dataframe.

# %%
len(df)
# Out:
# 1471

# %% [markdown]
# ## Export dataframe to a CSV
#
# Now we export the dataframe to a CSV file. Make sure you don't overwrite another one that is useful.

# %%
FileName = "FrequenciesResultsShort.csv" # assign a file name
df.to_csv(FileName) # write out to CSV
print("Done")
# Out:
# Done

# %% [markdown]
# ### What can you do with the CSV?
#
# The CSV can be openned in Excel and you can edit it. You could sort it by different texts or words. You can delete the rows for the words you are not interested in. You can then import the CSV into the Principal Component Analysis notebook to see what the components are.

# %% [markdown]
# Now we can check to see what the start of the file contains.

# %%
# !head -n 3 FrequeciesResultsShort.csv
# Out:
# head: FrequeciesResultsShort.csv: No such file or directory

# %% [markdown]
# ## Flip the dataframe
#
# Now we flip the dataframe so we can operate on the words. Note that you can save this dataframe too as a CSV if you want.

# %%
df2 = df.transpose()
df2.head(20)
# Out:
#                                                          the        to  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.014815  0.044444
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.058626  0.030151
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.039106  0.022346
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.036697  0.027523
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.067442  0.032558
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.043228  0.025937
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.046647  0.036443
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.012407  0.057072
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.030888  0.023166
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.054348  0.015217
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.058419  0.020619
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.070938  0.043478
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.031553  0.031553
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.057416  0.045455
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.030488  0.015244
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.046584  0.027950
# Sum                                                 0.699603  0.499157
#
#                                                          and        of  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.014815  0.011111
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.023451  0.025126
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.016760  0.011173
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.013761  0.009174
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.016279  0.032558
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.043228  0.031700
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.040816  0.018950
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.007444  0.002481
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.030888  0.027027
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.021739  0.039130
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.037801  0.020619
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.022883  0.025172
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.021845  0.021845
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.035885  0.019139
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.018293  0.024390
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.031056  0.018634
# Sum                                                 0.396943  0.338229
#
#                                                            u        is  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.007407  0.018519
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.011725  0.008375
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.016760  0.016760
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.018349  0.013761
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.011628  0.018605
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.005764  0.008646
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.007289  0.010204
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.007444  0.003722
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.019305  0.007722
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.008696  0.013043
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.018900  0.010309
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.009153  0.006865
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.016990  0.012136
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.014354  0.009569
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.021341  0.015244
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.015528  0.009317
# Sum                                                 0.210634  0.182797
#
#                                                           in        on  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.011111  0.011111
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.015075  0.018425
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.005587  0.011173
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.018349  0.018349
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.011628  0.006977
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.025937  0.017291
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.020408  0.004373
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.003722  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN  0.003861
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.023913  0.008696
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.003436  0.013746
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.013730  0.016018
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN  0.007282
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.011962  0.009569
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.006098  0.009146
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN  0.006211
# Sum                                                 0.170955  0.163469
#
#                                                          sid    sigint  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.007407  0.014815
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN  0.001675
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN  0.005587
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.018349  0.013761
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.009302  0.030233
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.005764  0.002882
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.001458  0.007289
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241       NaN
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.030888  0.023166
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN  0.002174
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.008591  0.001718
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.002288  0.009153
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.033981  0.007282
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.011962       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.024390  0.024390
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.003106  0.012422
# Sum                                                 0.158726  0.156547
#
#                                                       ...      pending  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...    ...          NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...    ...          NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...    ...          NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...    ...          NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...    ...          NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...    ...          NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...    ...          NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...    ...     0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...    ...          NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt       ...          NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...    ...          NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...    ...          NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...    ...          NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...    ...          NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...    ...          NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...    ...          NaN
# Sum                                                   ...     0.001241
#
#                                                         bump     group  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN       NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN       NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN       NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN       NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN       NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN       NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN       NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN       NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN       NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN       NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN       NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN       NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN       NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN       NaN
# Sum                                                 0.001241  0.001241
#
#                                                        intro  introduction  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN           NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN           NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN           NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN           NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN           NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN           NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN           NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241      0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN           NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN           NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN           NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN           NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN           NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN           NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN           NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN           NaN
# Sum                                                 0.001241      0.001241
#
#                                                       signed    unable  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN       NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN       NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN       NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN       NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN       NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN       NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN       NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN       NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN       NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN       NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN       NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN       NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN       NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN       NaN
# Sum                                                 0.001241  0.001241
#
#                                                          ais  demystifying  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN           NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN           NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN           NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN           NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN           NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN           NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN           NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241      0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN           NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN           NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN           NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN           NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN           NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN           NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN           NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN           NaN
# Sum                                                 0.001241      0.001241
#
#                                                     required
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN
# Sum                                                 0.001241
#
# [17 rows x 1471 columns]

# %% [markdown]
# ## Get rid of Sum row
#
# We are next going to start plotting words across the texts so we need to get rid of the Sum row.

# %%
df3 = df2.drop(['Sum'])
df3.head(18)
# Out:
#                                                          the        to  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.014815  0.044444
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.058626  0.030151
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.039106  0.022346
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.036697  0.027523
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.067442  0.032558
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.043228  0.025937
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.046647  0.036443
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.012407  0.057072
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.030888  0.023166
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.054348  0.015217
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.058419  0.020619
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.070938  0.043478
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.031553  0.031553
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.057416  0.045455
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.030488  0.015244
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.046584  0.027950
#
#                                                          and        of  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.014815  0.011111
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.023451  0.025126
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.016760  0.011173
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.013761  0.009174
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.016279  0.032558
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.043228  0.031700
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.040816  0.018950
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.007444  0.002481
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.030888  0.027027
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.021739  0.039130
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.037801  0.020619
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.022883  0.025172
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.021845  0.021845
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.035885  0.019139
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.018293  0.024390
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.031056  0.018634
#
#                                                            u        is  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.007407  0.018519
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.011725  0.008375
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.016760  0.016760
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.018349  0.013761
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.011628  0.018605
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.005764  0.008646
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.007289  0.010204
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.007444  0.003722
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.019305  0.007722
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.008696  0.013043
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.018900  0.010309
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.009153  0.006865
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.016990  0.012136
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.014354  0.009569
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.021341  0.015244
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.015528  0.009317
#
#                                                           in        on  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.011111  0.011111
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...  0.015075  0.018425
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...  0.005587  0.011173
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.018349  0.018349
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.011628  0.006977
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.025937  0.017291
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.020408  0.004373
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.003722  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN  0.003861
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt     0.023913  0.008696
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.003436  0.013746
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.013730  0.016018
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN  0.007282
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.011962  0.009569
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.006098  0.009146
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN  0.006211
#
#                                                          sid    sigint  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...  0.007407  0.014815
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN  0.001675
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN  0.005587
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...  0.018349  0.013761
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...  0.009302  0.030233
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...  0.005764  0.002882
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...  0.001458  0.007289
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241       NaN
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...  0.030888  0.023166
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN  0.002174
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...  0.008591  0.001718
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...  0.002288  0.009153
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...  0.033981  0.007282
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...  0.011962       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...  0.024390  0.024390
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...  0.003106  0.012422
#
#                                                       ...      pending  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...    ...          NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...    ...          NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...    ...          NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...    ...          NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...    ...          NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...    ...          NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...    ...          NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...    ...     0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...    ...          NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt       ...          NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...    ...          NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...    ...          NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...    ...          NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...    ...          NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...    ...          NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...    ...          NaN
#
#                                                         bump     group  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN       NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN       NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN       NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN       NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN       NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN       NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN       NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN       NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN       NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN       NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN       NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN       NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN       NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN       NaN
#
#                                                        intro  introduction  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN           NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN           NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN           NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN           NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN           NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN           NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN           NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241      0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN           NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN           NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN           NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN           NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN           NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN           NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN           NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN           NaN
#
#                                                       signed    unable  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN       NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN       NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN       NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN       NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN       NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN       NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN       NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN       NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN       NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN       NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN       NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN       NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN       NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN       NaN
#
#                                                          ais  demystifying  \
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN           NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN           NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN           NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN           NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN           NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN           NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN           NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241      0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN           NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN           NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN           NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN           NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN           NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN           NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN           NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN           NaN
#
#                                                     required
# 2003-04-01_SIDToday_-_Deployed_SIGINT_Analysts-...       NaN
# 2003-04-01_SIDToday_-_Practical_Jokes_and_April...       NaN
# 2003-04-02_SIDToday_-_Last_QUICKMASK_Training_T...       NaN
# 2003-04-02_SIDToday_-_New_Hire_Whats_On_Your_Mi...       NaN
# 2003-04-02_SIDToday_-_SIGINT_Strategy__The_Impo...       NaN
# 2003-04-03_SIDToday_-_GEOCELL_Supports_IRAQI_FR...       NaN
# 2003-04-03_SIDToday_-_SID_Leadership_Transition...       NaN
# 2003-04-03_SIDToday_-_Schedule_for_3rd_and_4th_...  0.001241
# 2003-04-04_SIDToday_-_Profiles_SID_Communicatio...       NaN
# 2003-04-04_SIDToday_-_Read_All_About_Us.pdf.txt          NaN
# 2003-04-07_SIDToday_-_ICAP_Call_for_Application...       NaN
# 2003-04-07_SIDToday_-_Support_to_UN_Diplomatic_...       NaN
# 2003-04-08_SIDToday_-_Profile_SID_Registry_-_Gr...       NaN
# 2003-04-08_SIDToday_-_Promotion_Cycle_Recap.pdf...       NaN
# 2003-04-09_SIDToday_-_Profile_SIGINT_Support_Se...       NaN
# 2003-04-09_SIDToday_-_Uncovering_North_Korea_Nu...       NaN
#
# [16 rows x 1471 columns]

# %% [markdown]
# ## Save the flipped file

# %%
FileName = "FrequenciesResultsShortFlip.csv" # assign a file name
df3.to_csv(FileName, na_rep=0) # write out to CSV
print("Done")
# Out:
# Done

# %% [markdown]
# ## Graphing a word over the files
#
# Now we can graph different words over the files we have.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

word2Plot = "possible" # change this to see different words

plt.figure(figsize=(16, 16))
# plt.rcParams.update({'font.size': 12})
df3[[word2Plot]].plot()
plt.title('Histogram of ' + word2Plot)
plt.show()

# %% [markdown]
# *Note* that the labels on the X axis are hard to read. It may be best to rename your text files or edit the CSV.
